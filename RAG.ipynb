# %%
from util.config import load_configuration

PROP_FILE = 'app.properties'
configs = load_configuration(PROP_FILE)

API_TYPE = configs.get("API_TYPE").data
API_VERSION = configs.get("API_VERSION").data
API_KEY = configs.get("API_KEY").data
API_BASE = configs.get("API_BASE").data
LLM_ENGINE_GPT35_16K=configs.get("LLM_ENGINE_GPT35_16K").data
ADA_MODEL=configs.get("ADA_MODEL").data

# %%
from langchain_openai import AzureChatOpenAI
from langchain_openai import AzureOpenAIEmbeddings

embeddings = AzureOpenAIEmbeddings(
    azure_endpoint=API_BASE,
    azure_deployment=ADA_MODEL,
     api_key=API_KEY,
    openai_api_version=API_VERSION,
)

llm = AzureChatOpenAI(
    azure_endpoint=API_BASE,
    api_key=API_KEY,
    azure_deployment=LLM_ENGINE_GPT35_16K,
    openai_api_version=API_VERSION,
)

# %%
pip install langchain_chroma
# Out:
# Collecting langchain_chroma
#   Using cached langchain_chroma-0.1.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting chromadb<0.5.0,>=0.4.0 (from langchain_chroma)
#   Using cached chromadb-0.4.24-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: fastapi<1,>=0.95.2 in /usr/lib/python3.8/site-packages (from langchain_chroma) (0.108.0)
# Requirement already satisfied: langchain-core<0.2.0,>=0.1.40 in /usr/lib/python3.8/site-packages (from langchain_chroma) (0.1.50)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.8/dist-packages (from langchain_chroma) (1.24.4)
# Collecting build>=1.0.3 (from chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached build-1.2.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: requests>=2.28 in /usr/local/lib/python3.8/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.5.3)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.7.3)
# Requirement already satisfied: uvicorn>=0.18.3 in /usr/lib/python3.8/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.23.2)
# Requirement already satisfied: posthog>=2.4.0 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (4.9.0)
# Requirement already satisfied: pulsar-client>=3.1.0 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.16.0)
# Collecting opentelemetry-api>=1.2.0 (from chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_api-1.24.0-py3-none-any.whl.metadata (1.3 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_instrumentation_fastapi-0.45b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_sdk-1.24.0-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.15.0)
# Requirement already satisfied: pypika>=0.48.9 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.8/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /usr/local/lib/python3.8/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (7.4.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.8/dist-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (6.0.1)
# Requirement already satisfied: grpcio>=1.58.0 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.62.2)
# Requirement already satisfied: bcrypt>=4.0.1 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.9.0)
# Collecting kubernetes>=28.1.0 (from chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached kubernetes-29.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (8.2.3)
# Collecting PyYAML>=6.0.0 (from chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Requirement already satisfied: mmh3>=4.0.1 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.10.0)
# Requirement already satisfied: graphlib-backport>=1.0.3 in /usr/lib/python3.8/site-packages (from chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.0.3)
# Requirement already satisfied: starlette<0.33.0,>=0.29.0 in /usr/lib/python3.8/site-packages (from fastapi<1,>=0.95.2->langchain_chroma) (0.32.0.post1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/lib/python3.8/site-packages (from langchain-core<0.2.0,>=0.1.40->langchain_chroma) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /usr/lib/python3.8/site-packages (from langchain-core<0.2.0,>=0.1.40->langchain_chroma) (0.1.54)
# Requirement already satisfied: packaging<24.0,>=23.2 in /usr/lib/python3.8/site-packages (from langchain-core<0.2.0,>=0.1.40->langchain_chroma) (23.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached pyproject_hooks-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: importlib-metadata>=4.6 in /usr/lib/python3.8/site-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (7.0.1)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from build>=1.0.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.0.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/lib/python3/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.2.0,>=0.1.40->langchain_chroma) (2.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2024.2.2)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.14.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.8/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /usr/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.25.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /usr/local/lib/python3.8/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.6.2)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.8/dist-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.3.1)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in /usr/lib/python3.8/site-packages (from kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.1.0)
# Requirement already satisfied: coloredlogs in /usr/lib/python3.8/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/lib/python3.8/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (23.5.26)
# Requirement already satisfied: protobuf in /usr/lib/python3.8/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (4.24.3)
# Requirement already satisfied: sympy in /usr/lib/python3.8/site-packages (from onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.12)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting importlib-metadata>=4.6 (from build>=1.0.3->chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached importlib_metadata-7.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /usr/lib/python3.8/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.62.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-proto==1.24.0 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_proto-1.24.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-asgi==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_instrumentation_asgi-0.45b0-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-instrumentation==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_instrumentation-0.45b0-py3-none-any.whl.metadata (6.1 kB)
# Collecting opentelemetry-semantic-conventions==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-util-http==0.45b0 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached opentelemetry_util_http-0.45b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: setuptools>=16.0 in /usr/lib/python3/dist-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (45.2.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /usr/lib/python3.8/site-packages (from opentelemetry-instrumentation==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.16.0)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.45b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb<0.5.0,>=0.4.0->langchain_chroma)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Requirement already satisfied: monotonic>=1.5 in /usr/lib/python3.8/site-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/lib/python3.8/site-packages (from posthog>=2.4.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.2.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/lib/python3.8/site-packages (from pydantic>=1.9->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.5.0)
# Requirement already satisfied: pydantic-core==2.14.6 in /usr/lib/python3.8/site-packages (from pydantic>=1.9->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.14.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.28->chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.28->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2.8)
# Requirement already satisfied: anyio<5,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from starlette<0.33.0,>=0.29.0->fastapi<1,>=0.95.2->langchain_chroma) (3.7.1)
# Requirement already satisfied: huggingface_hub<1.0,>=0.16.4 in /usr/lib/python3.8/site-packages (from tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.19.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3.8/site-packages (from typer>=0.9.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (8.1.7)
# Requirement already satisfied: h11>=0.8 in /usr/lib/python3.8/site-packages (from uvicorn>=0.18.3->uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /usr/lib/python3.8/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.6.0)
# Requirement already satisfied: python-dotenv>=0.13 in /usr/lib/python3.8/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.0.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /usr/lib/python3.8/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.17.0)
# Requirement already satisfied: watchfiles>=0.13 in /usr/lib/python3.8/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.20.0)
# Requirement already satisfied: websockets>=10.4 in /usr/lib/python3.8/site-packages (from uvicorn[standard]>=0.18.3->chromadb<0.5.0,>=0.4.0->langchain_chroma) (11.0.3)
# Requirement already satisfied: zipp>=3.1.0 in /usr/lib/python3.8/site-packages (from importlib-resources->chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.17.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.8/dist-packages (from anyio<5,>=3.4.0->starlette<0.33.0,>=0.29.0->fastapi<1,>=0.95.2->langchain_chroma) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.8/dist-packages (from anyio<5,>=3.4.0->starlette<0.33.0,>=0.29.0->fastapi<1,>=0.95.2->langchain_chroma) (1.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/lib/python3.8/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/lib/python3/dist-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/lib/python3.8/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (4.9)
# Requirement already satisfied: filelock in /usr/lib/python3.8/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.0->langchain_chroma) (3.12.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/lib/python3.8/site-packages (from huggingface_hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb<0.5.0,>=0.4.0->langchain_chroma) (2023.9.2)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/lib/python3.8/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/lib/python3.8/site-packages (from sympy->onnxruntime>=1.14.1->chromadb<0.5.0,>=0.4.0->langchain_chroma) (1.3.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/lib/python3/dist-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb<0.5.0,>=0.4.0->langchain_chroma) (0.4.2)
# Using cached langchain_chroma-0.1.0-py3-none-any.whl (8.5 kB)
# Using cached chromadb-0.4.24-py3-none-any.whl (525 kB)
# Using cached build-1.2.1-py3-none-any.whl (21 kB)
# Using cached kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
# Using cached opentelemetry_api-1.24.0-py3-none-any.whl (60 kB)
# Using cached opentelemetry_exporter_otlp_proto_grpc-1.24.0-py3-none-any.whl (18 kB)
# Using cached opentelemetry_exporter_otlp_proto_common-1.24.0-py3-none-any.whl (17 kB)
# Using cached opentelemetry_proto-1.24.0-py3-none-any.whl (50 kB)
# Using cached opentelemetry_instrumentation_fastapi-0.45b0-py3-none-any.whl (11 kB)
# Using cached opentelemetry_instrumentation-0.45b0-py3-none-any.whl (28 kB)
# Using cached opentelemetry_instrumentation_asgi-0.45b0-py3-none-any.whl (14 kB)
# Using cached opentelemetry_semantic_conventions-0.45b0-py3-none-any.whl (36 kB)
# Using cached opentelemetry_util_http-0.45b0-py3-none-any.whl (6.9 kB)
# Using cached opentelemetry_sdk-1.24.0-py3-none-any.whl (106 kB)
# Using cached PyYAML-6.0.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (736 kB)
# Using cached Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Using cached importlib_metadata-7.0.0-py3-none-any.whl (23 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached pyproject_hooks-1.1.0-py3-none-any.whl (9.2 kB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Installing collected packages: PyYAML, pyproject_hooks, opentelemetry-util-http, opentelemetry-semantic-conventions, opentelemetry-proto, oauthlib, importlib-metadata, deprecated, asgiref, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, build, opentelemetry-sdk, opentelemetry-instrumentation, kubernetes, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb, langchain_chroma
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 5.3.1
# ERROR: Cannot uninstall 'PyYAML'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
# Note: you may need to restart the kernel to use updated packages.

# %%
import bs4
from langchain import hub
from langchain_community.document_loaders import WebBaseLoader
from langchain_chroma import Chroma
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import OpenAIEmbeddings
from langchain_text_splitters import RecursiveCharacterTextSplitter
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 from langchain import hub
#       3 from langchain_community.document_loaders import WebBaseLoader
# ----> 4 from langchain_chroma import Chroma
#       5 from langchain_core.output_parsers import StrOutputParser
#       6 from langchain_core.runnables import RunnablePassthrough
#
# ModuleNotFoundError: No module named 'langchain_chroma'

# %%
# Load, chunk and index the contents of the blog.
loader = WebBaseLoader(
    web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
    bs_kwargs=dict(
        parse_only=bs4.SoupStrainer(
            class_=("post-content", "post-title", "post-header")
        )
    ),
)
docs = loader.load()

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
splits = text_splitter.split_documents(docs)
vectorstore = Chroma.from_documents(documents=splits, embedding=OpenAIEmbeddings())

# Retrieve and generate using the relevant snippets of the blog.
retriever = vectorstore.as_retriever()
prompt = hub.pull("rlm/rag-prompt")

def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)


rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

rag_chain.invoke("What is Task Decomposition?")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Load, chunk and index the contents of the blog.
# ----> 2 loader = WebBaseLoader(
#       3     web_paths=("https://lilianweng.github.io/posts/2023-06-23-agent/",),
#       4     bs_kwargs=dict(
#       5         parse_only=bs4.SoupStrainer(
#       6             class_=("post-content", "post-title", "post-header")
#       7         )
#       8     ),
#       9 )
#      10 docs = loader.load()
#      12 text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
#
# NameError: name 'WebBaseLoader' is not defined
